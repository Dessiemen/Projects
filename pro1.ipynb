# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {'Year':[2004, 2005, 2006, 2007, 2008, 2009,2010],
        'Sales1':[40, 60,80, 30,45,90, 25],
         'Sales2':[50, 60,85,30,70,40, 80]}

# %%
df = pd.DataFrame(data)

# %%
da = {'Name': ['Ali', 'Keli', 'Mafi'], 'Age': [34, 45, 39], 'City': ['Addis', 'DT', 'Gonder']}
df7 = pd.DataFrame(da)

df7[['Total Name Age', 'Full Name City']] = df7.apply(lambda x: pd.Series((x['Name'] + ' ' + str(x['Age']), x['Name'] + ' '+ str(x['Age'])+' ' + x['City'])), axis=1)

print(df7)
# Out:
#    Name  Age    City Total Name Age  Full Name City
# 0   Ali   34   Addis         Ali 34    Ali 34 Addis
# 1  Keli   45      DT        Keli 45      Keli 45 DT
# 2  Mafi   39  Gonder        Mafi 39  Mafi 39 Gonder

# %%
df['Sales3'] = [70,50,60,80,40,80,70]

# %%
df
# Out:
#    Year  Sales1  Sales2  Sales3
# 0  2004      40      50      70
# 1  2005      60      60      50
# 2  2006      80      85      60
# 3  2007      30      30      80
# 4  2008      45      70      40
# 5  2009      90      40      80
# 6  2010      25      80      70

# %%
df.loc[3, 'Sales1'] = [40]

# %%
df
# Out:
#    Year  Sales1  Sales2  Sales3
# 0  2004      40      50      70
# 1  2005      60      60      50
# 2  2006      80      85      60
# 3  2007      40      30      80
# 4  2008      45      70      40
# 5  2009      90      40      80
# 6  2010      25      80      70

# %%
 df.plot(x = "Year", y = ['Sales1', 'Sales2','Sales3'], ylabel= "Sales", figsize=(10,4), color= ["red", "green","blue"], linewidth = 3 )
# Out:
# <Axes: xlabel='Year', ylabel='Sales'>

# %%
vg= pd.read_csv(r'C:\Users\tinsu\Desktop\Analysis Project\vgSales.csv')

# %%
vg
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vg.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
vg1 = vg.dropna()

# %%
vg1.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
vg1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
vg1 = vg1.reset_index()

# %%
vg1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16291 entries, 0 to 16290
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         16291 non-null  int64
#  1   Rank          16291 non-null  int64
#  2   Name          16291 non-null  object
#  3   Platform      16291 non-null  object
#  4   Year          16291 non-null  float64
#  5   Genre         16291 non-null  object
#  6   Publisher     16291 non-null  object
#  7   NA_Sales      16291 non-null  float64
#  8   EU_Sales      16291 non-null  float64
#  9   JP_Sales      16291 non-null  float64
#  10  Other_Sales   16291 non-null  float64
#  11  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 1.5+ MB

# %%
vg1['Year'] = vg1['Year'].astype(int)

# %%
vg1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16291 entries, 0 to 16290
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         16291 non-null  int64
#  1   Rank          16291 non-null  int64
#  2   Name          16291 non-null  object
#  3   Platform      16291 non-null  object
#  4   Year          16291 non-null  int32
#  5   Genre         16291 non-null  object
#  6   Publisher     16291 non-null  object
#  7   NA_Sales      16291 non-null  float64
#  8   EU_Sales      16291 non-null  float64
#  9   JP_Sales      16291 non-null  float64
#  10  Other_Sales   16291 non-null  float64
#  11  Global_Sales  16291 non-null  float64
# dtypes: float64(5), int32(1), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
vg2 = vg1[['Year','NA_Sales','EU_Sales', 'JP_Sales', 'Other_Sales','Global_Sales']]

# %%
vg2
# Out:
#        Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      2006     41.49     29.02      3.77         8.46         82.74
# 1      1985     29.08      3.58      6.81         0.77         40.24
# 2      2008     15.85     12.88      3.79         3.31         35.82
# 3      2009     15.75     11.01      3.28         2.96         33.00
# 4      1996     11.27      8.89     10.22         1.00         31.37
# ...     ...       ...       ...       ...          ...           ...
# 16286  2002      0.01      0.00      0.00         0.00          0.01
# 16287  2003      0.01      0.00      0.00         0.00          0.01
# 16288  2008      0.00      0.00      0.00         0.00          0.01
# 16289  2010      0.00      0.01      0.00         0.00          0.01
# 16290  2003      0.01      0.00      0.00         0.00          0.01
#
# [16291 rows x 6 columns]

# %%
vg3 = vg2.groupby('Year').sum()

# %%
vg3
# Out:
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 1980     10.59      0.67      0.00         0.12         11.38
# 1981     33.40      1.96      0.00         0.32         35.77
# 1982     26.92      1.65      0.00         0.31         28.86
# 1983      7.76      0.80      8.10         0.14         16.79
# 1984     33.28      2.10     14.27         0.70         50.36
# 1985     33.73      4.74     14.56         0.92         53.94
# 1986     12.50      2.84     19.81         1.93         37.07
# 1987      8.46      1.41     11.63         0.20         21.74
# 1988     23.87      6.59     15.76         0.99         47.22
# 1989     45.15      8.44     18.36         1.50         73.45
# 1990     25.46      7.63     14.88         1.40         49.39
# 1991     12.76      3.95     14.78         0.74         32.23
# 1992     33.87     11.71     28.91         1.65         76.16
# 1993     15.12      4.65     25.33         0.89         45.98
# ...

# %%
vg3.plot(ylabel = 'Sales')
# Out:
# <Axes: xlabel='Year', ylabel='Sales'>
